# %%
#1. Leia o dataset usando pandas.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Salary_Data.csv')
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#2.Converta os dados relevantes em arrays NumPy (utilize o método .to_numpy())

anos_experiencia = df['YearsExperience'].to_numpy()
salario = df['Salary'].to_numpy()

print("Anos de Experiência:")
print(anos_experiencia)
print("\nSalário:")
print(salario)
# Out:
# Anos de Experiência:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
#
# Salário:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
#3.Calcule a média de salários.
media_salarios = np.mean(y)

print(f"A média dos salários é R$ {media_salarios:.2f}")
# Out:
# A média dos salários é R$ 76003.00

# %%
#4.Calcule a média de tempo de serviço.
media_tempo_servico = np.mean(X)

print(f"A média do tempo de serviço é {media_tempo_servico:.2f} anos")
# Out:
# A média do tempo de serviço é 5.31 anos

# %%
#5.Encontre o salário médio dos funcionários com mais de 5 anos de serviço.

mais_5_anos = X > 5

salarios_mais_5_anos = y[mais_5_anos]

media_salarios_mais_5_anos = np.mean(salarios_mais_5_anos)

print(f"O salário médio dos funcionários com mais de 5 anos de serviço é: R$ {media_salarios_mais_5_anos:.2f}")
# Out:
# O salário médio dos funcionários com mais de 5 anos de serviço é: R$ 101316.07
# Número de funcionários com mais de 5 anos de serviço: 14

# %%
#6.Crie um gráfico de barras mostrando os salários referente ao tempo de serviço.
salarios_por_experiencia = df.groupby('YearsExperience')['Salary'].mean().round(2)

salarios_por_experiencia.plot(kind='bar')
plt.title('Salários Médios por Tempo de Serviço')
plt.xlabel('Anos de Experiência')
plt.ylabel('Salário Médio (R$)')
plt.show()

# %%
#7.Considere um aumento de 10% para o salário de cada funcionário e apresente o resultado do aumento.
novos_salarios = y * 1.10
aumento = novos_salarios - y

print("Resultados do aumento de 10%:")
print("\nAumento")

for aumento_valor in aumento:
    print(f"R$ {aumento_valor:.2f}")

media_aumento = np.mean(aumento)
# Out:
# Resultados do aumento de 10%:
#
# Aumento
# R$ 3934.30
# R$ 4620.50
# R$ 3773.10
# R$ 4352.50
# R$ 3989.10
# R$ 5664.20
# R$ 6015.00
# R$ 5444.50
# R$ 6444.50
# R$ 5718.90
# R$ 6321.80
# R$ 5579.40
# R$ 5695.70
# R$ 5708.10
# R$ 6111.10
# R$ 6793.80
# R$ 6602.90
# R$ 8308.80
# R$ 8136.30
# R$ 9394.00
# R$ 9173.80
# R$ 9827.30
# R$ 10130.20
# R$ 11381.20
# R$ 10943.10
# R$ 10558.20
# R$ 11696.90
# R$ 11263.50
# R$ 12239.10
# R$ 12187.20
